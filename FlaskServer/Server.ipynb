# %%
# !pip install ultralytics torch torchvision opencv-python matplotlib
from ultralytics import YOLO
import cv2
import numpy as np
from PIL import Image
import torch
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
MODEL_PATH = 'best.pt'  # Change to your uploaded .pt file
TEST_IMAGE = 'answerset_1.png'       # Upload a test image
CONF_THRESHOLD = 0.1
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
model = YOLO(MODEL_PATH).to(DEVICE)
print(f"Model loaded on {DEVICE.upper()}")
def detect_and_visualize(image_path):
    # Run inference
    results = model(image_path, conf=CONF_THRESHOLD)

    # Show results
    for r in results:
        im_array = r.plot()  # Plot with bounding boxes
        im = Image.fromarray(im_array[..., ::-1])  # BGR to RGB
        plt.figure(figsize=(12, 8))
        plt.imshow(im)
        plt.axis('off')
        plt.show()

        # Print detections
        print("Detections:")
        for box in r.boxes:
            # Convert box.conf to a float before formatting
            conf_score = box.conf.item()
            print(f"- {model.names[int(box.cls)]} ({conf_score:.2f})")
            
detect_and_visualize(TEST_IMAGE)
# Out:
# ...
#   Using cached torch-2.6.0-cp312-cp312-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# ...
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# ...
#    ---------------------------------------- 0.0/977.1 kB ? eta -:--:--
#    ---------------------------------------- 977.1/977.1 kB 9.2 MB/s eta 0:00:00
# Using cached torch-2.6.0-cp312-cp312-win_amd64.whl (204.1 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Using cached ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# ...
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
# ...

# %%
# !pip install ultralytics torch torchvision opencv-python matplotlib

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from PIL import Image
import torch
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
MODEL_PATH = 'best.pt'  # Change to your uploaded .pt file
TEST_IMAGE = 'answerset_1.png'       # Upload a test image
CONF_THRESHOLD = 0.3
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
model = YOLO(MODEL_PATH).to(DEVICE)
print(f"Model loaded on {DEVICE.upper()}")
# Out:
# Model loaded on CPU

# %%
def detect_and_visualize(image_path):
    # Run inference
    results = model(image_path, conf=CONF_THRESHOLD)

    # Show results
    for r in results:
        im_array = r.plot()  # Plot with bounding boxes
        im = Image.fromarray(im_array[..., ::-1])  # BGR to RGB
        plt.figure(figsize=(12, 8))
        plt.imshow(im)
        plt.axis('off')
        plt.show()

        # Print detections
        print("Detections:")
        for box in r.boxes:
            # Convert box.conf to a float before formatting
            conf_score = box.conf.item()
            print(f"- {model.names[int(box.cls)]} ({conf_score:.2f})")

# %%
detect_and_visualize(TEST_IMAGE)
# Out:
# image 1/1 c:\Users\SATHVIK\OneDrive\Desktop\React Native\AiAnswerEvaluator\Python_Backend\answerset_1.png: 544x640 2 0s, 2 1s, 2 2s, 117.3ms
# Speed: 4.4ms preprocess, 117.3ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
# Detections:
# - 1 (0.97)
# - 1 (0.96)
# - 2 (0.93)
# - 2 (0.93)
# - 0 (0.59)
# - 0 (0.47)
